# %% [markdown]
# # Keras Basics
# We will learn about
# * Dense layers
# * Categorical cross-entropy
#
# A toy example to show how to train a classifier with Keras and use it. The data comes from three gaussian distributions.

# %%
## DATA GENERATION
import numpy as np

def generateX(cls):
    '''
    Inputs:
        cls: class {0, 1, 2}
    Outputs:
        x: a sample from cls; a np array of shape (2,)
    '''
    assert cls in [0,1,2]
    if cls==0:
        x = np.random.normal(np.array([0,0]),100)
    elif cls==1:
        x = np.random.normal(np.array([200,200]),100)
    elif cls==2:
        x = np.random.normal(np.array([-200,200]),100)
    return x
Nx = 2 # shape of a sample is (2,)
Ny = 3 # 3 classes

# %% [markdown]
# Could you write a function to generate N samples from class 0 and N samples from class 1?

# %%
def generateXY(N):
    '''
    Inputs:
        N: no. of samples of each class
    Outputs:
        X: np array of samples; shape = (3*N, 2)
        Y: np array of samples; shape = (3*N, 1)
    '''
    ### BEGIN SOLUTION
    Y = []
    X = []
    for cls in range(3):
        for i in range(N):
            y = cls
            x = generateX(y)
            x = x.T
            Y.append(y)
            X.append(x)
            
    X = np.concatenate(X, axis=0)
    Y = np.array(Y).reshape(-1,1)
    print(X.shape)
    print(Y.shape)
    ### END SOLUTION
    return X, Y

# %%
generateXY(2)
# Out:
# (12,)
# (6, 1)
# (array([  -2.46248519,   88.97101011,   98.17803086,   28.15876393,
#           69.71732   ,  386.23102841,  261.74662955,  192.44266996,
#         -177.8753798 ,  219.97131131, -117.66757717,  296.8895933 ]),
#  array([[0],
#         [0],
#         [1],
#         [1],
#         [2],
#         [2]]))
# (12,)
# (6, 1)
# (array([  34.43249175,   53.42217875,  139.11600101,  -15.19093646,
#          346.160616  ,   99.23072789,  329.10556395,   42.13586047,
#         -257.50244645,  216.44064506, -183.68008812,   58.66970643]),
#  array([[0],
#         [0],
#         [1],
#         [1],
#         [2],
#         [2]]))

# %%
def generateXY(N):
    '''
    Inputs:
        N: no. of samples of each class
    Outputs:
        X: np array of samples; shape = (3*N, 2)
        Y: np array of samples; shape = (3*N, 1)
    '''
    
    ### BEGIN SOLUTION
    Y = [0]*N + [1]*N + [2]*N   # a list of 0s and 1s as ground truth classes  
    X = [generateX(y) for y in Y]  # samples corresponding to the ground truth Y
    X = np.vstack(X)   # arrange samples in different rows
    Y = np.array(Y).reshape(-1,1)
    ### END SOLUTION
    return X, Y

# %%
def test_generateXY():
    X_train, Y_train = generateXY(50)
    assert X_train.shape==(150,2)
    assert Y_train.shape==(150,1)
    print('Test passed', '\U0001F44D')
test_generateXY()
# Out:
# Test passed 👍
# Test passed 👍

# %% [markdown]
# ### One-hot encoding
#
# Now our Y is in the form [0], [1] and [2]. We want to convert them to [1,0,0], [0,1,0] and [0,0,1], respectively.
# Could you write a code to convert Y (with one column) into one-hot encoded Y (with 3 columns)?

# %%
def oneHot(y, Ny):
    '''
    Input:
        y: an int in {0, 1, 2}
        Ny: Number of classes, e.g., 3 here
    Output:
        Y: a vector of Ny (=3) tuples
    '''
    
    ### BEGIN SOLUTION
    Y = np.zeros(Ny)
    Y[y] = 1
    ### END SOLUTION
    return Y

# %%
def test_oneHot():
    assert np.all(oneHot(0,3)==np.array([1,0,0]))
    assert np.all(oneHot(1,3)==np.array([0,1,0]))
    assert np.all(oneHot(2,3)==np.array([0,0,1]))
    print('Test passed', '\U0001F44D')
test_oneHot()
# Out:
# Test passed 👍
# Test passed 👍

# %% [markdown]
# ### Input Normalization
# X can lie in any unbounded range. We need to curtail to a narrow range close to zero. This helps in enhancing the stability of training and hyper-parameter tuning.
# This is normally achieved by scaling the X to have zero mean and unit standard deviation (std).
#
# $X \leftarrow \frac{X-mean(X)}{std(X)}$, where this is element wise division
#
# Could you use training samples to find mean and std, and normalize your X_train with that?

# %%
def findMeanStddev(X):
    '''
    Input: 
        X: a matrix of size (no. of samples, dimension of each sample)
    Output:
        mean: mean of samples in X; shape is (dimension of each sample,)
        stddev: element-wise std dev of sample in X; shape is (dimension of each sample,)
    '''
    ### BEGIN SOLUTION
    mean = np.sum(X, axis=0)/X.shape[0]
    X1 = X - mean
    stddev = np.sqrt(np.sum(X1*X1, axis=0)/X.shape[0])
    ### END SOLUTION
    return mean, stddev

# %%
def test_findMeanStddev():
    X = np.array([[3,2,6],[7,4,2],[3,5,1]])
    mean, stddev = findMeanStddev(X)
    assert np.isclose(mean, np.array([4.33, 3.66, 3.]), atol=0.1).all()
    assert np.isclose(stddev, np.array([1.88, 1.24, 2.16]), atol=0.1).all()
    print('Test passed', '\U0001F44D')
test_findMeanStddev()
# Out:
# Test passed 👍
# Test passed 👍

# %%
def normalizeX(X, mean, stddev):
    '''
    Input:
        X: a matrix of size (no. of samples, dimension of each sample)
        mean: mean of samples in X (same size as X)
        stddev: element-wise std dev of sample in X (same size as X) 
    Output:
        Xn: X modified to have 0 mean and 1 std dev
    '''
    ### BEGIN SOLUTION
    Xn = (X-mean)/(stddev+1e-8)
    ### END SOLUTION
    return Xn

# %%
def test_normalizeX():
    X = np.ones((3,3))
    m,s = findMeanStddev(X)
    assert np.all(m==np.ones(3))
    assert np.all(s==np.zeros(3))
    assert np.all(normalizeX(X,m,s)==0*X)
    # test on random X
    X = np.random.random((5,3))
    m,s = findMeanStddev(X)
    Xn = normalizeX(X,m,s)
    mn, sn = findMeanStddev(Xn)
    assert np.allclose(mn, np.zeros(3))
    assert np.allclose(sn, np.ones(3))
    print('Test passed', '\U0001F44D')
test_normalizeX()
# Out:
# Test passed 👍
# Test passed 👍

# %% [markdown]
# ### Plotting
# Could you plot all the samples in X_train with different colors for different classes?

# %%
import matplotlib.pyplot as plt
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
def plotXY(X, Y):
    '''
    Inputs:
        X: a matrix of size (no. of samples, dimension of each sample)
        Y: a matrix of size (no. of samples, no. of classes) - these are one-hot vectors
    Action:
        Plots the samples in X, their color depends on Y
    '''
    Ny = Y.shape[1]
    for cls in range(Ny):
        idx = np.where(Y[:,cls]==1)[0]
        plt.plot(X[idx,0], X[idx,1], colors[cls]+'.')

# %% [markdown]
# ## Creating the Network
# We now create the network with dense layers:
# $y = f(Wx)$
#
# ReLU activation:
# $f(h) = h, h>0; 0, h\le 0$
#
# Softmax activation:
# $f(h_i) = \frac{\exp(h_i)}{\sum_j \exp(h_j)}$
#
# Categorical cross-entropy loss:
# $\mathcal{L} = -\sum_t y^d_t \log y_t$
#
# Stochastic Gradient Descent:
# $w_{ij} \leftarrow w_{ij} - \eta \frac{\partial \mathcal{L}}{\partial w_{ij}}$

# %%
import keras
from keras.layers import Input, Dense
from keras.models import Model
from keras import optimizers

def makeNN(Nx, Nh, Ny):
    '''
    Input:
        Nx: int; no. of input nodes; shape of each sample; i.e., X.shape[1:] 
        Nh: int; no. of hidden neurons
        Ny: int; no. of output nodes; shape of output; i.e., Y.shape[1]
    Output:
        model: keras NN model with Input layer, Dense layer with Nh neurons, 
                and Dense output layer with softmax non-linearity, loss function
                categorical-crossentropy, optimizer SGD.
    '''
    ### BEGIN SOLUTION
    x = Input(shape=(Nx,))
    y = Dense(20, activation='relu')(x)
    y = Dense(Ny, activation='softmax')(y)
    model = Model(inputs=x, outputs=y)
    model.compile(optimizer=optimizers.sgd(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    ### END SOLUTION
    return model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Plotting the model

# %%
def plotModel(model):
    from keras.utils import plot_model
    plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
    from IPython.display import Image
    Image(retina=True, filename='model.png')

# %% [markdown]
# ### Training

# %%
def trainNN(model, X_train, Y_train, Nepochs):
    '''
    Action:
        Train model with model.fit
    '''
    ### BEGIN SOLUTION
    history = model.fit(X_train, Y_train, epochs=Nepochs) # validation_split = 0.1
    ### END SOLUTION

# %%
def trainModel(N, Nh, Nepochs):
    '''
    generateXY, normalizeX, oneHot, makeNN, trainNN
    Input:
        N: int; no. of training samples per class
        Nh: int; no. of neurons in hidden layer
    Output:
        model: keras NN model trained with the training data
        mean_train, stddev_train: mean and stddev of training data - you will 
                            need this for normalizing your test data
    '''
    ### BEGIN SOLUTION
    X_train, Y_train_int = generateXY(N)
    Nx = X_train.shape[1]
    mean_train, stddev_train = findMeanStddev(X_train)
    X_train = normalizeX(X_train, mean_train, stddev_train)
    Ny = 3
    Y_train = np.array([oneHot(y,Ny) for y in Y_train_int])
    plotXY(X_train, Y_train)
    model = makeNN(Nx, Nh, Ny)
    trainNN(model, X_train, Y_train, Nepochs)
    ### END SOLUTION
    return model, mean_train, stddev_train

# %% [markdown]
# ### Evaluation
# Could you:
# - Generate 20 samples from each class
# - Normalize them with mean_train and stddev_train
# - Get Y_test as one hot encoded labels

# %%
def testModel(model, Ntest, mean_train, stddev_train):
    '''
    generateXY for test, normalize, onehot, evaluate the model
    Inputs:
        model: trained Keras NN model
        Ntest: int; number of test samples per class
    Output:
        accuracy: float; accuracy on the test data
        CM: confusion matrix on the test data
    '''
    ### BEGIN SOLUTION
    ## Data preparation
    X_test, Y_test_int = generateXY(20)
    X_test = normalizeX(X_test, mean_train, stddev_train)
    Y_test = np.array([oneHot(y,Ny) for y in Y_test_int])
    ## Evaluation
    loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)  # Evaluate the model
    print('Accuracy :%0.3f'%accuracy)
    Y_pred = model.predict(X_test)
    ## Confusion Matrix
    from sklearn.metrics import confusion_matrix
    CM = confusion_matrix(Y_test.argmax(axis=1), Y_pred.argmax(axis=1)) 
    ### END SOLUTION
    return accuracy, CM

# %%
model, mean_train, stddev_train = trainModel(50, 20, 300)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0622 13:23:08.716289 139823367473024 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0622 13:23:08.758025 139823367473024 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0622 13:23:08.766313 139823367473024 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0622 13:23:08.822166 139823367473024 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0622 13:23:08.837253 139823367473024 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0622 13:23:08.983135 139823367473024 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0622 13:23:09.039097 139823367473024 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                60
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 63
# =================================================================
# Total params: 123
# Trainable params: 123
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 150/150 [==============================] - 1s 5ms/step - loss: 1.1788 - acc: 0.3200
# Epoch 2/300
# 150/150 [==============================] - 0s 91us/step - loss: 1.1766 - acc: 0.3267
# Epoch 3/300
# 150/150 [==============================] - 0s 67us/step - loss: 1.1744 - acc: 0.3267
# Epoch 4/300
# 150/150 [==============================] - 0s 74us/step - loss: 1.1723 - acc: 0.3267
# Epoch 5/300
# 150/150 [==============================] - 0s 63us/step - loss: 1.1701 - acc: 0.3267
# Epoch 6/300
# 150/150 [==============================] - 0s 64us/step - loss: 1.1680 - acc: 0.3267
# Epoch 7/300
# 150/150 [==============================] - 0s 75us/step - loss: 1.1659 - acc: 0.3267
# Epoch 8/300
# 150/150 [==============================] - 0s 69us/step - loss: 1.1638 - acc: 0.3267
# Epoch 9/300
# 150/150 [==============================] - 0s 59us/step - loss: 1.1617 - acc: 0.3267
# Epoch 10/300
# 150/150 [==============================] - 0s 67us/step - loss: 1.1596 - acc: 0.3333
# Epoch 11/300
# 150/150 [==============================] - 0s 60us/step - loss: 1.1575 - acc: 0.3333
# Epoch 12/300
# 150/150 [==============================] - 0s 66us/step - loss: 1.1554 - acc: 0.3333
# Epoch 13/300
# 150/150 [==============================] - 0s 70us/step - loss: 1.1534 - acc: 0.3333
# Epoch 14/300
# 150/150 [==============================] - 0s 66us/step - loss: 1.1514 - acc: 0.3333
# Epoch 15/300
# 150/150 [==============================] - 0s 74us/step - loss: 1.1494 - acc: 0.3333
# Epoch 16/300
# 150/150 [==============================] - 0s 70us/step - loss: 1.1474 - acc: 0.3333
# Epoch 17/300
# 150/150 [==============================] - 0s 87us/step - loss: 1.1454 - acc: 0.3333
# Epoch 18/300
# 150/150 [==============================] - 0s 71us/step - loss: 1.1434 - acc: 0.3333
# Epoch 19/300
# 150/150 [==============================] - 0s 87us/step - loss: 1.1415 - acc: 0.3333
# Epoch 20/300
# 150/150 [==============================] - 0s 78us/step - loss: 1.1396 - acc: 0.3333
# Epoch 21/300
# 150/150 [==============================] - 0s 89us/step - loss: 1.1377 - acc: 0.3333
# Epoch 22/300
# 150/150 [==============================] - 0s 68us/step - loss: 1.1358 - acc: 0.3333
# Epoch 23/300
# 150/150 [==============================] - 0s 71us/step - loss: 1.1339 - acc: 0.3333
# Epoch 24/300
# 150/150 [==============================] - 0s 62us/step - loss: 1.1320 - acc: 0.3333
# Epoch 25/300
# 150/150 [==============================] - 0s 53us/step - loss: 1.1301 - acc: 0.3333
# Epoch 26/300
# 150/150 [==============================] - 0s 77us/step - loss: 1.1283 - acc: 0.3333
# Epoch 27/300
# 150/150 [==============================] - 0s 63us/step - loss: 1.1265 - acc: 0.3333
# Epoch 28/300
# 150/150 [==============================] - 0s 61us/step - loss: 1.1247 - acc: 0.3333
# Epoch 29/300
# 150/150 [==============================] - 0s 62us/step - loss: 1.1229 - acc: 0.3333
# Epoch 30/300
# 150/150 [==============================] - 0s 83us/step - loss: 1.1211 - acc: 0.3333
# Epoch 31/300
# 150/150 [==============================] - 0s 115us/step - loss: 1.1194 - acc: 0.3333
# Epoch 32/300
# 150/150 [==============================] - 0s 62us/step - loss: 1.1176 - acc: 0.3333
# Epoch 33/300
# 150/150 [==============================] - 0s 58us/step - loss: 1.1159 - acc: 0.3333
# Epoch 34/300
# 150/150 [==============================] - 0s 66us/step - loss: 1.1141 - acc: 0.3333
# Epoch 35/300
# 150/150 [==============================] - 0s 72us/step - loss: 1.1124 - acc: 0.3333
# Epoch 36/300
# 150/150 [==============================] - 0s 69us/step - loss: 1.1107 - acc: 0.3333
# Epoch 37/300
# 150/150 [==============================] - 0s 62us/step - loss: 1.1090 - acc: 0.3333
# Epoch 38/300
# 150/150 [==============================] - 0s 62us/step - loss: 1.1073 - acc: 0.3333
# Epoch 39/300
# 150/150 [==============================] - 0s 68us/step - loss: 1.1057 - acc: 0.3333
# Epoch 40/300
# 150/150 [==============================] - 0s 76us/step - loss: 1.1040 - acc: 0.3333
# Epoch 41/300
# 150/150 [==============================] - 0s 67us/step - loss: 1.1023 - acc: 0.3333
# Epoch 42/300
# 150/150 [==============================] - 0s 67us/step - loss: 1.1006 - acc: 0.3333
# Epoch 43/300
# 150/150 [==============================] - 0s 76us/step - loss: 1.0990 - acc: 0.3333
# Epoch 44/300
# 150/150 [==============================] - 0s 70us/step - loss: 1.0973 - acc: 0.3333
# Epoch 45/300
# 150/150 [==============================] - 0s 57us/step - loss: 1.0957 - acc: 0.3333
# Epoch 46/300
# 150/150 [==============================] - 0s 82us/step - loss: 1.0941 - acc: 0.3333
# Epoch 47/300
# 150/150 [==============================] - 0s 97us/step - loss: 1.0924 - acc: 0.3333
# Epoch 48/300
# 150/150 [==============================] - 0s 78us/step - loss: 1.0908 - acc: 0.3333
# Epoch 49/300
# 150/150 [==============================] - 0s 116us/step - loss: 1.0892 - acc: 0.3333
# Epoch 50/300
# 150/150 [==============================] - 0s 85us/step - loss: 1.0876 - acc: 0.3333
# Epoch 51/300
# 150/150 [==============================] - 0s 74us/step - loss: 1.0860 - acc: 0.3333
# Epoch 52/300
# 150/150 [==============================] - 0s 100us/step - loss: 1.0844 - acc: 0.3333
# Epoch 53/300
# 150/150 [==============================] - 0s 63us/step - loss: 1.0828 - acc: 0.3333
# Epoch 54/300
# 150/150 [==============================] - 0s 65us/step - loss: 1.0813 - acc: 0.3333
# Epoch 55/300
# 150/150 [==============================] - 0s 58us/step - loss: 1.0797 - acc: 0.3333
# Epoch 56/300
# 150/150 [==============================] - 0s 66us/step - loss: 1.0782 - acc: 0.3333
# Epoch 57/300
# 150/150 [==============================] - 0s 135us/step - loss: 1.0766 - acc: 0.3333
# Epoch 58/300
# 150/150 [==============================] - 0s 64us/step - loss: 1.0751 - acc: 0.3333
# Epoch 59/300
# 150/150 [==============================] - 0s 62us/step - loss: 1.0735 - acc: 0.3333
# Epoch 60/300
# 150/150 [==============================] - 0s 63us/step - loss: 1.0719 - acc: 0.3333
# Epoch 61/300
# 150/150 [==============================] - 0s 61us/step - loss: 1.0704 - acc: 0.3333
# Epoch 62/300
# 150/150 [==============================] - 0s 67us/step - loss: 1.0689 - acc: 0.3333
# Epoch 63/300
# 150/150 [==============================] - 0s 61us/step - loss: 1.0673 - acc: 0.3333
# Epoch 64/300
# 150/150 [==============================] - 0s 59us/step - loss: 1.0658 - acc: 0.3333
# Epoch 65/300
# 150/150 [==============================] - 0s 58us/step - loss: 1.0643 - acc: 0.3333
# Epoch 66/300
# 150/150 [==============================] - 0s 58us/step - loss: 1.0628 - acc: 0.3400
# Epoch 67/300
# 150/150 [==============================] - 0s 61us/step - loss: 1.0613 - acc: 0.3467
# Epoch 68/300
# 150/150 [==============================] - 0s 61us/step - loss: 1.0598 - acc: 0.3467
# Epoch 69/300
# 150/150 [==============================] - 0s 72us/step - loss: 1.0583 - acc: 0.3533
# Epoch 70/300
# 150/150 [==============================] - 0s 79us/step - loss: 1.0568 - acc: 0.3533
# Epoch 71/300
# 150/150 [==============================] - 0s 73us/step - loss: 1.0554 - acc: 0.3533
# Epoch 72/300
# 150/150 [==============================] - 0s 65us/step - loss: 1.0539 - acc: 0.3533
# Epoch 73/300
# 150/150 [==============================] - 0s 89us/step - loss: 1.0524 - acc: 0.3600
# Epoch 74/300
# 150/150 [==============================] - 0s 78us/step - loss: 1.0509 - acc: 0.3600
# Epoch 75/300
# 150/150 [==============================] - 0s 70us/step - loss: 1.0494 - acc: 0.3667
# Epoch 76/300
# 150/150 [==============================] - 0s 65us/step - loss: 1.0480 - acc: 0.3667
# Epoch 77/300
# 150/150 [==============================] - 0s 70us/step - loss: 1.0465 - acc: 0.3667
# Epoch 78/300
# 150/150 [==============================] - 0s 68us/step - loss: 1.0450 - acc: 0.3733
# Epoch 79/300
# 150/150 [==============================] - 0s 74us/step - loss: 1.0436 - acc: 0.3733
# Epoch 80/300
# 150/150 [==============================] - 0s 76us/step - loss: 1.0421 - acc: 0.3800
# Epoch 81/300
# 150/150 [==============================] - 0s 80us/step - loss: 1.0407 - acc: 0.3800
# Epoch 82/300
# 150/150 [==============================] - 0s 78us/step - loss: 1.0392 - acc: 0.3800
# Epoch 83/300
# 150/150 [==============================] - 0s 101us/step - loss: 1.0378 - acc: 0.3800
# Epoch 84/300
# 150/150 [==============================] - 0s 73us/step - loss: 1.0363 - acc: 0.3800
# Epoch 85/300
# 150/150 [==============================] - 0s 70us/step - loss: 1.0349 - acc: 0.3800
# Epoch 86/300
# 150/150 [==============================] - 0s 60us/step - loss: 1.0335 - acc: 0.3867
# Epoch 87/300
# 150/150 [==============================] - 0s 85us/step - loss: 1.0321 - acc: 0.3867
# Epoch 88/300
# 150/150 [==============================] - 0s 74us/step - loss: 1.0306 - acc: 0.3933
# Epoch 89/300
# 150/150 [==============================] - 0s 91us/step - loss: 1.0292 - acc: 0.3933
# Epoch 90/300
# 150/150 [==============================] - 0s 56us/step - loss: 1.0278 - acc: 0.4000
# Epoch 91/300
# 150/150 [==============================] - 0s 68us/step - loss: 1.0264 - acc: 0.4000
# Epoch 92/300
# 150/150 [==============================] - 0s 73us/step - loss: 1.0250 - acc: 0.4000
# Epoch 93/300
# 150/150 [==============================] - 0s 66us/step - loss: 1.0237 - acc: 0.4000
# Epoch 94/300
# 150/150 [==============================] - 0s 66us/step - loss: 1.0223 - acc: 0.4000
# Epoch 95/300
# 150/150 [==============================] - 0s 75us/step - loss: 1.0209 - acc: 0.4067
# Epoch 96/300
# 150/150 [==============================] - 0s 78us/step - loss: 1.0196 - acc: 0.4067
# Epoch 97/300
# 150/150 [==============================] - 0s 82us/step - loss: 1.0182 - acc: 0.4067
# Epoch 98/300
# 150/150 [==============================] - 0s 76us/step - loss: 1.0168 - acc: 0.4067
# Epoch 99/300
# 150/150 [==============================] - 0s 77us/step - loss: 1.0155 - acc: 0.4067
# Epoch 100/300
# 150/150 [==============================] - 0s 79us/step - loss: 1.0141 - acc: 0.4067
# Epoch 101/300
# 150/150 [==============================] - 0s 72us/step - loss: 1.0128 - acc: 0.4067
# Epoch 102/300
# 150/150 [==============================] - 0s 70us/step - loss: 1.0115 - acc: 0.4067
# Epoch 103/300
# 150/150 [==============================] - 0s 77us/step - loss: 1.0101 - acc: 0.4067
# Epoch 104/300
# 150/150 [==============================] - 0s 79us/step - loss: 1.0088 - acc: 0.4133
# Epoch 105/300
# 150/150 [==============================] - 0s 74us/step - loss: 1.0075 - acc: 0.4133
# Epoch 106/300
# 150/150 [==============================] - 0s 68us/step - loss: 1.0062 - acc: 0.4133
# Epoch 107/300
# 150/150 [==============================] - 0s 72us/step - loss: 1.0048 - acc: 0.4133
# Epoch 108/300
# 150/150 [==============================] - 0s 59us/step - loss: 1.0036 - acc: 0.4200
# Epoch 109/300
# 150/150 [==============================] - 0s 76us/step - loss: 1.0022 - acc: 0.4200
# Epoch 110/300
# 150/150 [==============================] - 0s 62us/step - loss: 1.0010 - acc: 0.4200
# Epoch 111/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.9997 - acc: 0.4200
# Epoch 112/300
# 150/150 [==============================] - 0s 58us/step - loss: 0.9984 - acc: 0.4200
# Epoch 113/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.9971 - acc: 0.4267
# Epoch 114/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.9958 - acc: 0.4267
# Epoch 115/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.9945 - acc: 0.4267
# Epoch 116/300
# 150/150 [==============================] - 0s 86us/step - loss: 0.9933 - acc: 0.4267
# Epoch 117/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.9920 - acc: 0.4267
# Epoch 118/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9907 - acc: 0.4267
# Epoch 119/300
# 150/150 [==============================] - 0s 86us/step - loss: 0.9895 - acc: 0.4267
# Epoch 120/300
# 150/150 [==============================] - 0s 59us/step - loss: 0.9882 - acc: 0.4333
# Epoch 121/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.9869 - acc: 0.4333
# Epoch 122/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9857 - acc: 0.4333
# Epoch 123/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.9844 - acc: 0.4333
# Epoch 124/300
# 150/150 [==============================] - 0s 98us/step - loss: 0.9832 - acc: 0.4333
# Epoch 125/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9820 - acc: 0.4333
# Epoch 126/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.9807 - acc: 0.4333
# Epoch 127/300
# 150/150 [==============================] - 0s 56us/step - loss: 0.9795 - acc: 0.4333
# Epoch 128/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.9783 - acc: 0.4333
# Epoch 129/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.9770 - acc: 0.4333
# Epoch 130/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.9758 - acc: 0.4333
# Epoch 131/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.9746 - acc: 0.4333
# Epoch 132/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.9734 - acc: 0.4333
# Epoch 133/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.9722 - acc: 0.4333
# Epoch 134/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.9709 - acc: 0.4400
# Epoch 135/300
# 150/150 [==============================] - 0s 95us/step - loss: 0.9697 - acc: 0.4467
# Epoch 136/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.9686 - acc: 0.4467
# Epoch 137/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.9673 - acc: 0.4467
# Epoch 138/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.9662 - acc: 0.4467
# Epoch 139/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9650 - acc: 0.4467
# Epoch 140/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.9638 - acc: 0.4467
# Epoch 141/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.9626 - acc: 0.4467
# Epoch 142/300
# 150/150 [==============================] - 0s 104us/step - loss: 0.9615 - acc: 0.4467
# Epoch 143/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9603 - acc: 0.4467
# Epoch 144/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.9591 - acc: 0.4533
# Epoch 145/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9580 - acc: 0.4533
# Epoch 146/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.9568 - acc: 0.4667
# Epoch 147/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.9557 - acc: 0.4733
# Epoch 148/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.9545 - acc: 0.4733
# Epoch 149/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.9534 - acc: 0.4733
# Epoch 150/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.9523 - acc: 0.4733
# Epoch 151/300
# 150/150 [==============================] - 0s 94us/step - loss: 0.9511 - acc: 0.4733
# Epoch 152/300
# 150/150 [==============================] - 0s 61us/step - loss: 0.9500 - acc: 0.4733
# Epoch 153/300
# 150/150 [==============================] - 0s 126us/step - loss: 0.9489 - acc: 0.4867
# Epoch 154/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.9477 - acc: 0.4867
# Epoch 155/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9466 - acc: 0.4933
# Epoch 156/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.9455 - acc: 0.5000
# Epoch 157/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9444 - acc: 0.5067
# Epoch 158/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.9432 - acc: 0.5133
# Epoch 159/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9421 - acc: 0.5200
# Epoch 160/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.9410 - acc: 0.5267
# Epoch 161/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.9399 - acc: 0.5333
# Epoch 162/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9388 - acc: 0.5333
# Epoch 163/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.9377 - acc: 0.5333
# Epoch 164/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.9366 - acc: 0.5333
# Epoch 165/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9356 - acc: 0.5400
# Epoch 166/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.9345 - acc: 0.5533
# Epoch 167/300
# 150/150 [==============================] - 0s 92us/step - loss: 0.9334 - acc: 0.5600
# Epoch 168/300
# 150/150 [==============================] - 0s 50us/step - loss: 0.9323 - acc: 0.5600
# Epoch 169/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9312 - acc: 0.5600
# Epoch 170/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.9301 - acc: 0.5733
# Epoch 171/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.9290 - acc: 0.5867
# Epoch 172/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.9280 - acc: 0.5867
# Epoch 173/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.9269 - acc: 0.6000
# Epoch 174/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.9258 - acc: 0.6000
# Epoch 175/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9248 - acc: 0.6000
# Epoch 176/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9237 - acc: 0.6000
# Epoch 177/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.9226 - acc: 0.6000
# Epoch 178/300
# 150/150 [==============================] - 0s 59us/step - loss: 0.9216 - acc: 0.6067
# Epoch 179/300
# 150/150 [==============================] - 0s 87us/step - loss: 0.9205 - acc: 0.6133
# Epoch 180/300
# 150/150 [==============================] - 0s 61us/step - loss: 0.9194 - acc: 0.6133
# Epoch 181/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9184 - acc: 0.6133
# Epoch 182/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.9173 - acc: 0.6133
# Epoch 183/300
# 150/150 [==============================] - 0s 58us/step - loss: 0.9163 - acc: 0.6133
# Epoch 184/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.9153 - acc: 0.6267
# Epoch 185/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9142 - acc: 0.6333
# Epoch 186/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9132 - acc: 0.6267
# Epoch 187/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.9122 - acc: 0.6400
# Epoch 188/300
# 150/150 [==============================] - 0s 87us/step - loss: 0.9111 - acc: 0.6400
# Epoch 189/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9101 - acc: 0.6467
# Epoch 190/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.9090 - acc: 0.6467
# Epoch 191/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.9080 - acc: 0.6467
# Epoch 192/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.9070 - acc: 0.6600
# Epoch 193/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.9060 - acc: 0.6600
# Epoch 194/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.9050 - acc: 0.6667
# Epoch 195/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.9040 - acc: 0.6667
# Epoch 196/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.9029 - acc: 0.6667
# Epoch 197/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9019 - acc: 0.6800
# Epoch 198/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9009 - acc: 0.6800
# Epoch 199/300
# 150/150 [==============================] - 0s 83us/step - loss: 0.8999 - acc: 0.6800
# Epoch 200/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.8989 - acc: 0.6800
# Epoch 201/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.8979 - acc: 0.6800
# Epoch 202/300
# 150/150 [==============================] - 0s 84us/step - loss: 0.8969 - acc: 0.6867
# Epoch 203/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.8960 - acc: 0.6867
# Epoch 204/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.8950 - acc: 0.6867
# Epoch 205/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.8940 - acc: 0.6867
# Epoch 206/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.8930 - acc: 0.6800
# Epoch 207/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8920 - acc: 0.6800
# Epoch 208/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.8910 - acc: 0.6800
# Epoch 209/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.8900 - acc: 0.6867
# Epoch 210/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.8890 - acc: 0.7000
# Epoch 211/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.8881 - acc: 0.7000
# Epoch 212/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.8871 - acc: 0.7000
# Epoch 213/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.8862 - acc: 0.7000
# Epoch 214/300
# 150/150 [==============================] - 0s 83us/step - loss: 0.8852 - acc: 0.7000
# Epoch 215/300
# 150/150 [==============================] - 0s 92us/step - loss: 0.8842 - acc: 0.7000
# Epoch 216/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.8832 - acc: 0.7000
# Epoch 217/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.8823 - acc: 0.7000
# Epoch 218/300
# 150/150 [==============================] - 0s 93us/step - loss: 0.8813 - acc: 0.7000
# Epoch 219/300
# 150/150 [==============================] - 0s 53us/step - loss: 0.8804 - acc: 0.7000
# Epoch 220/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.8794 - acc: 0.7000
# Epoch 221/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.8785 - acc: 0.7000
# Epoch 222/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.8775 - acc: 0.7000
# Epoch 223/300
# 150/150 [==============================] - 0s 54us/step - loss: 0.8766 - acc: 0.7000
# Epoch 224/300
# 150/150 [==============================] - 0s 55us/step - loss: 0.8756 - acc: 0.7000
# Epoch 225/300
# 150/150 [==============================] - 0s 62us/step - loss: 0.8747 - acc: 0.7000
# Epoch 226/300
# 150/150 [==============================] - 0s 61us/step - loss: 0.8737 - acc: 0.7000
# Epoch 227/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.8728 - acc: 0.7000
# Epoch 228/300
# 150/150 [==============================] - 0s 61us/step - loss: 0.8718 - acc: 0.7000
# Epoch 229/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.8709 - acc: 0.7000
# Epoch 230/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.8699 - acc: 0.7000
# Epoch 231/300
# 150/150 [==============================] - 0s 62us/step - loss: 0.8690 - acc: 0.7000
# Epoch 232/300
# 150/150 [==============================] - 0s 57us/step - loss: 0.8681 - acc: 0.7000
# Epoch 233/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.8671 - acc: 0.7000
# Epoch 234/300
# 150/150 [==============================] - 0s 60us/step - loss: 0.8662 - acc: 0.7000
# Epoch 235/300
# 150/150 [==============================] - 0s 62us/step - loss: 0.8653 - acc: 0.7000
# Epoch 236/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.8644 - acc: 0.7000
# Epoch 237/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.8634 - acc: 0.7000
# Epoch 238/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.8625 - acc: 0.7000
# Epoch 239/300
# 150/150 [==============================] - 0s 58us/step - loss: 0.8616 - acc: 0.7000
# Epoch 240/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.8607 - acc: 0.7000
# Epoch 241/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.8598 - acc: 0.7000
# Epoch 242/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8589 - acc: 0.7000
# Epoch 243/300
# 150/150 [==============================] - 0s 111us/step - loss: 0.8580 - acc: 0.7000
# Epoch 244/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.8570 - acc: 0.7000
# Epoch 245/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.8561 - acc: 0.7000
# Epoch 246/300
# 150/150 [==============================] - 0s 86us/step - loss: 0.8552 - acc: 0.7000
# Epoch 247/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8544 - acc: 0.7000
# Epoch 248/300
# 150/150 [==============================] - 0s 62us/step - loss: 0.8535 - acc: 0.7000
# Epoch 249/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.8526 - acc: 0.7000
# Epoch 250/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.8517 - acc: 0.7000
# Epoch 251/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8508 - acc: 0.7000
# Epoch 252/300
# 150/150 [==============================] - 0s 93us/step - loss: 0.8499 - acc: 0.7000
# Epoch 253/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.8490 - acc: 0.7000
# Epoch 254/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.8481 - acc: 0.7133
# Epoch 255/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.8472 - acc: 0.7133
# Epoch 256/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.8463 - acc: 0.7133
# Epoch 257/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.8454 - acc: 0.7133
# Epoch 258/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.8445 - acc: 0.7133
# Epoch 259/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.8437 - acc: 0.7133
# Epoch 260/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.8428 - acc: 0.7133
# Epoch 261/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8419 - acc: 0.7200
# Epoch 262/300
# 150/150 [==============================] - 0s 53us/step - loss: 0.8410 - acc: 0.7200
# Epoch 263/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.8401 - acc: 0.7200
# Epoch 264/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.8393 - acc: 0.7200
# Epoch 265/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.8384 - acc: 0.7267
# Epoch 266/300
# 150/150 [==============================] - 0s 62us/step - loss: 0.8375 - acc: 0.7333
# Epoch 267/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.8367 - acc: 0.7467
# Epoch 268/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.8358 - acc: 0.7467
# Epoch 269/300
# 150/150 [==============================] - 0s 67us/step - loss: 0.8349 - acc: 0.7467
# Epoch 270/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.8341 - acc: 0.7467
# Epoch 271/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.8332 - acc: 0.7533
# Epoch 272/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.8324 - acc: 0.7533
# Epoch 273/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.8315 - acc: 0.7600
# Epoch 274/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.8306 - acc: 0.7600
# Epoch 275/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.8298 - acc: 0.7600
# Epoch 276/300
# 150/150 [==============================] - 0s 94us/step - loss: 0.8290 - acc: 0.7600
# Epoch 277/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8281 - acc: 0.7667
# Epoch 278/300
# 150/150 [==============================] - 0s 93us/step - loss: 0.8273 - acc: 0.7667
# Epoch 279/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8264 - acc: 0.7667
# Epoch 280/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.8256 - acc: 0.7667
# Epoch 281/300
# 150/150 [==============================] - 0s 84us/step - loss: 0.8247 - acc: 0.7733
# Epoch 282/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8239 - acc: 0.7800
# Epoch 283/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.8230 - acc: 0.7800
# Epoch 284/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.8222 - acc: 0.7867
# Epoch 285/300
# 150/150 [==============================] - 0s 106us/step - loss: 0.8214 - acc: 0.7933
# Epoch 286/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.8205 - acc: 0.7933
# Epoch 287/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.8197 - acc: 0.7933
# Epoch 288/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.8189 - acc: 0.7933
# Epoch 289/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.8180 - acc: 0.7933
# Epoch 290/300
# 150/150 [==============================] - 0s 61us/step - loss: 0.8172 - acc: 0.7933
# Epoch 291/300
# 150/150 [==============================] - 0s 87us/step - loss: 0.8164 - acc: 0.7933
# Epoch 292/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.8156 - acc: 0.7933
# Epoch 293/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8147 - acc: 0.7933
# Epoch 294/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.8139 - acc: 0.7933
# Epoch 295/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.8131 - acc: 0.7933
# Epoch 296/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.8123 - acc: 0.7933
# Epoch 297/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.8115 - acc: 0.7933
# Epoch 298/300
# 150/150 [==============================] - 0s 96us/step - loss: 0.8107 - acc: 0.7933
# Epoch 299/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.8098 - acc: 0.7933
# Epoch 300/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.8090 - acc: 0.7933
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                60
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 63
# =================================================================
# Total params: 123
# Trainable params: 123
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 150/150 [==============================] - 0s 964us/step - loss: 1.0252 - acc: 0.3733
# Epoch 2/300
# 150/150 [==============================] - 0s 54us/step - loss: 1.0237 - acc: 0.3667
# Epoch 3/300
# 150/150 [==============================] - 0s 62us/step - loss: 1.0222 - acc: 0.3667
# Epoch 4/300
# 150/150 [==============================] - 0s 60us/step - loss: 1.0207 - acc: 0.3667
# Epoch 5/300
# 150/150 [==============================] - 0s 67us/step - loss: 1.0192 - acc: 0.3667
# Epoch 6/300
# 150/150 [==============================] - 0s 132us/step - loss: 1.0177 - acc: 0.3667
# Epoch 7/300
# 150/150 [==============================] - 0s 70us/step - loss: 1.0162 - acc: 0.3733
# Epoch 8/300
# 150/150 [==============================] - 0s 101us/step - loss: 1.0148 - acc: 0.3733
# Epoch 9/300
# 150/150 [==============================] - 0s 54us/step - loss: 1.0132 - acc: 0.3800
# Epoch 10/300
# 150/150 [==============================] - 0s 80us/step - loss: 1.0118 - acc: 0.3800
# Epoch 11/300
# 150/150 [==============================] - 0s 73us/step - loss: 1.0103 - acc: 0.3800
# Epoch 12/300
# 150/150 [==============================] - 0s 72us/step - loss: 1.0089 - acc: 0.3800
# Epoch 13/300
# 150/150 [==============================] - 0s 83us/step - loss: 1.0074 - acc: 0.3800
# Epoch 14/300
# 150/150 [==============================] - 0s 82us/step - loss: 1.0060 - acc: 0.3800
# Epoch 15/300
# 150/150 [==============================] - 0s 80us/step - loss: 1.0045 - acc: 0.3733
# Epoch 16/300
# 150/150 [==============================] - 0s 81us/step - loss: 1.0031 - acc: 0.3733
# Epoch 17/300
# 150/150 [==============================] - 0s 82us/step - loss: 1.0016 - acc: 0.3733
# Epoch 18/300
# 150/150 [==============================] - 0s 57us/step - loss: 1.0002 - acc: 0.3733
# Epoch 19/300
# 150/150 [==============================] - 0s 108us/step - loss: 0.9988 - acc: 0.3733
# Epoch 20/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9973 - acc: 0.3733
# Epoch 21/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.9959 - acc: 0.3867
# Epoch 22/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.9945 - acc: 0.3933
# Epoch 23/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.9931 - acc: 0.3933
# Epoch 24/300
# 150/150 [==============================] - 0s 97us/step - loss: 0.9917 - acc: 0.3933
# Epoch 25/300
# 150/150 [==============================] - 0s 86us/step - loss: 0.9903 - acc: 0.3933
# Epoch 26/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9890 - acc: 0.3933
# Epoch 27/300
# 150/150 [==============================] - 0s 92us/step - loss: 0.9876 - acc: 0.3933
# Epoch 28/300
# 150/150 [==============================] - 0s 91us/step - loss: 0.9862 - acc: 0.3933
# Epoch 29/300
# 150/150 [==============================] - 0s 100us/step - loss: 0.9849 - acc: 0.4000
# Epoch 30/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9835 - acc: 0.4133
# Epoch 31/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9822 - acc: 0.4133
# Epoch 32/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9808 - acc: 0.4133
# Epoch 33/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.9795 - acc: 0.4067
# Epoch 34/300
# 150/150 [==============================] - 0s 137us/step - loss: 0.9781 - acc: 0.4067
# Epoch 35/300
# 150/150 [==============================] - 0s 106us/step - loss: 0.9768 - acc: 0.4133
# Epoch 36/300
# 150/150 [==============================] - 0s 95us/step - loss: 0.9755 - acc: 0.4133
# Epoch 37/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.9741 - acc: 0.4133
# Epoch 38/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.9728 - acc: 0.4067
# Epoch 39/300
# 150/150 [==============================] - 0s 86us/step - loss: 0.9715 - acc: 0.4133
# Epoch 40/300
# 150/150 [==============================] - 0s 88us/step - loss: 0.9702 - acc: 0.4133
# Epoch 41/300
# 150/150 [==============================] - 0s 87us/step - loss: 0.9689 - acc: 0.4133
# Epoch 42/300
# 150/150 [==============================] - 0s 90us/step - loss: 0.9676 - acc: 0.4200
# Epoch 43/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9663 - acc: 0.4333
# Epoch 44/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.9651 - acc: 0.4333
# Epoch 45/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.9638 - acc: 0.4333
# Epoch 46/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.9625 - acc: 0.4467
# Epoch 47/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.9612 - acc: 0.4667
# Epoch 48/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9599 - acc: 0.4667
# Epoch 49/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.9587 - acc: 0.4733
# Epoch 50/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9574 - acc: 0.4800
# Epoch 51/300
# 150/150 [==============================] - 0s 90us/step - loss: 0.9561 - acc: 0.4867
# Epoch 52/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.9549 - acc: 0.4933
# Epoch 53/300
# 150/150 [==============================] - 0s 119us/step - loss: 0.9536 - acc: 0.5067
# Epoch 54/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.9524 - acc: 0.5133
# Epoch 55/300
# 150/150 [==============================] - 0s 83us/step - loss: 0.9511 - acc: 0.5133
# Epoch 56/300
# 150/150 [==============================] - 0s 89us/step - loss: 0.9499 - acc: 0.5267
# Epoch 57/300
# 150/150 [==============================] - 0s 125us/step - loss: 0.9486 - acc: 0.5400
# Epoch 58/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.9474 - acc: 0.5467
# Epoch 59/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9463 - acc: 0.5533
# Epoch 60/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9450 - acc: 0.5667
# Epoch 61/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9438 - acc: 0.5733
# Epoch 62/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.9426 - acc: 0.5800
# Epoch 63/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.9414 - acc: 0.5867
# Epoch 64/300
# 150/150 [==============================] - 0s 84us/step - loss: 0.9403 - acc: 0.5867
# Epoch 65/300
# 150/150 [==============================] - 0s 88us/step - loss: 0.9391 - acc: 0.5933
# Epoch 66/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.9379 - acc: 0.6133
# Epoch 67/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.9367 - acc: 0.6133
# Epoch 68/300
# 150/150 [==============================] - 0s 62us/step - loss: 0.9355 - acc: 0.6200
# Epoch 69/300
# 150/150 [==============================] - 0s 110us/step - loss: 0.9344 - acc: 0.6200
# Epoch 70/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.9332 - acc: 0.6200
# Epoch 71/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.9320 - acc: 0.6267
# Epoch 72/300
# 150/150 [==============================] - 0s 141us/step - loss: 0.9309 - acc: 0.6267
# Epoch 73/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.9297 - acc: 0.6267
# Epoch 74/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9286 - acc: 0.6267
# Epoch 75/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.9274 - acc: 0.6267
# Epoch 76/300
# 150/150 [==============================] - 0s 86us/step - loss: 0.9263 - acc: 0.6267
# Epoch 77/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9252 - acc: 0.6267
# Epoch 78/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.9240 - acc: 0.6267
# Epoch 79/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.9229 - acc: 0.6267
# Epoch 80/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.9218 - acc: 0.6267
# Epoch 81/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.9207 - acc: 0.6267
# Epoch 82/300
# 150/150 [==============================] - 0s 88us/step - loss: 0.9196 - acc: 0.6267
# Epoch 83/300
# 150/150 [==============================] - 0s 92us/step - loss: 0.9185 - acc: 0.6267
# Epoch 84/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.9174 - acc: 0.6267
# Epoch 85/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.9163 - acc: 0.6267
# Epoch 86/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.9151 - acc: 0.6267
# Epoch 87/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.9140 - acc: 0.6267
# Epoch 88/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9130 - acc: 0.6267
# Epoch 89/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.9119 - acc: 0.6267
# Epoch 90/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9108 - acc: 0.6267
# Epoch 91/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9097 - acc: 0.6267
# Epoch 92/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.9087 - acc: 0.6333
# Epoch 93/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.9076 - acc: 0.6333
# Epoch 94/300
# 150/150 [==============================] - 0s 87us/step - loss: 0.9065 - acc: 0.6333
# Epoch 95/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.9054 - acc: 0.6333
# Epoch 96/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9044 - acc: 0.6333
# Epoch 97/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.9033 - acc: 0.6333
# Epoch 98/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.9023 - acc: 0.6333
# Epoch 99/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.9012 - acc: 0.6333
# Epoch 100/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.9002 - acc: 0.6333
# Epoch 101/300
# 150/150 [==============================] - 0s 95us/step - loss: 0.8991 - acc: 0.6267
# Epoch 102/300
# 150/150 [==============================] - 0s 55us/step - loss: 0.8981 - acc: 0.6333
# Epoch 103/300
# 150/150 [==============================] - 0s 49us/step - loss: 0.8971 - acc: 0.6333
# Epoch 104/300
# 150/150 [==============================] - 0s 50us/step - loss: 0.8961 - acc: 0.6333
# Epoch 105/300
# 150/150 [==============================] - 0s 52us/step - loss: 0.8950 - acc: 0.6333
# Epoch 106/300
# 150/150 [==============================] - 0s 53us/step - loss: 0.8941 - acc: 0.6333
# Epoch 107/300
# 150/150 [==============================] - 0s 97us/step - loss: 0.8931 - acc: 0.6333
# Epoch 108/300
# 150/150 [==============================] - 0s 114us/step - loss: 0.8921 - acc: 0.6333
# Epoch 109/300
# 150/150 [==============================] - 0s 148us/step - loss: 0.8911 - acc: 0.6333
# Epoch 110/300
# 150/150 [==============================] - 0s 120us/step - loss: 0.8900 - acc: 0.6333
# Epoch 111/300
# 150/150 [==============================] - 0s 83us/step - loss: 0.8890 - acc: 0.6333
# Epoch 112/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.8881 - acc: 0.6333
# Epoch 113/300
# 150/150 [==============================] - 0s 98us/step - loss: 0.8870 - acc: 0.6333
# Epoch 114/300
# 150/150 [==============================] - 0s 141us/step - loss: 0.8861 - acc: 0.6333
# Epoch 115/300
# 150/150 [==============================] - 0s 83us/step - loss: 0.8850 - acc: 0.6333
# Epoch 116/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.8841 - acc: 0.6333
# Epoch 117/300
# 150/150 [==============================] - 0s 114us/step - loss: 0.8831 - acc: 0.6333
# Epoch 118/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.8821 - acc: 0.6333
# Epoch 119/300
# 150/150 [==============================] - 0s 95us/step - loss: 0.8811 - acc: 0.6333
# Epoch 120/300
# 150/150 [==============================] - 0s 62us/step - loss: 0.8802 - acc: 0.6333
# Epoch 121/300
# 150/150 [==============================] - 0s 87us/step - loss: 0.8792 - acc: 0.6333
# Epoch 122/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.8782 - acc: 0.6333
# Epoch 123/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.8773 - acc: 0.6333
# Epoch 124/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.8763 - acc: 0.6333
# Epoch 125/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.8753 - acc: 0.6333
# Epoch 126/300
# 150/150 [==============================] - 0s 57us/step - loss: 0.8744 - acc: 0.6333
# Epoch 127/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8735 - acc: 0.6333
# Epoch 128/300
# 150/150 [==============================] - 0s 84us/step - loss: 0.8725 - acc: 0.6333
# Epoch 129/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.8716 - acc: 0.6333
# Epoch 130/300
# 150/150 [==============================] - 0s 100us/step - loss: 0.8707 - acc: 0.6333
# Epoch 131/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.8697 - acc: 0.6333
# Epoch 132/300
# 150/150 [==============================] - 0s 110us/step - loss: 0.8688 - acc: 0.6333
# Epoch 133/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.8678 - acc: 0.6333
# Epoch 134/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.8669 - acc: 0.6333
# Epoch 135/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.8660 - acc: 0.6333
# Epoch 136/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.8651 - acc: 0.6333
# Epoch 137/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.8641 - acc: 0.6333
# Epoch 138/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.8632 - acc: 0.6333
# Epoch 139/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.8623 - acc: 0.6333
# Epoch 140/300
# 150/150 [==============================] - 0s 87us/step - loss: 0.8614 - acc: 0.6333
# Epoch 141/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.8605 - acc: 0.6333
# Epoch 142/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.8596 - acc: 0.6333
# Epoch 143/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.8587 - acc: 0.6333
# Epoch 144/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.8578 - acc: 0.6333
# Epoch 145/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.8569 - acc: 0.6333
# Epoch 146/300
# 150/150 [==============================] - 0s 98us/step - loss: 0.8560 - acc: 0.6333
# Epoch 147/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.8551 - acc: 0.6333
# Epoch 148/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.8542 - acc: 0.6333
# Epoch 149/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.8533 - acc: 0.6333
# Epoch 150/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.8524 - acc: 0.6333
# Epoch 151/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.8515 - acc: 0.6333
# Epoch 152/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.8507 - acc: 0.6333
# Epoch 153/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.8498 - acc: 0.6333
# Epoch 154/300
# 150/150 [==============================] - 0s 58us/step - loss: 0.8489 - acc: 0.6333
# Epoch 155/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.8480 - acc: 0.6400
# Epoch 156/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.8472 - acc: 0.6400
# Epoch 157/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.8463 - acc: 0.6467
# Epoch 158/300
# 150/150 [==============================] - 0s 58us/step - loss: 0.8454 - acc: 0.6400
# Epoch 159/300
# 150/150 [==============================] - 0s 111us/step - loss: 0.8445 - acc: 0.6467
# Epoch 160/300
# 150/150 [==============================] - 0s 119us/step - loss: 0.8437 - acc: 0.6467
# Epoch 161/300
# 150/150 [==============================] - 0s 62us/step - loss: 0.8429 - acc: 0.6467
# Epoch 162/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.8420 - acc: 0.6467
# Epoch 163/300
# 150/150 [==============================] - 0s 149us/step - loss: 0.8411 - acc: 0.6467
# Epoch 164/300
# 150/150 [==============================] - 0s 89us/step - loss: 0.8403 - acc: 0.6467
# Epoch 165/300
# 150/150 [==============================] - 0s 84us/step - loss: 0.8395 - acc: 0.6467
# Epoch 166/300
# 150/150 [==============================] - 0s 110us/step - loss: 0.8386 - acc: 0.6467
# Epoch 167/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.8378 - acc: 0.6467
# Epoch 168/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.8369 - acc: 0.6467
# Epoch 169/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.8361 - acc: 0.6533
# Epoch 170/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.8353 - acc: 0.6533
# Epoch 171/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.8344 - acc: 0.6533
# Epoch 172/300
# 150/150 [==============================] - 0s 59us/step - loss: 0.8336 - acc: 0.6533
# Epoch 173/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.8328 - acc: 0.6533
# Epoch 174/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.8319 - acc: 0.6533
# Epoch 175/300
# 150/150 [==============================] - 0s 92us/step - loss: 0.8311 - acc: 0.6533
# Epoch 176/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.8303 - acc: 0.6533
# Epoch 177/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.8295 - acc: 0.6533
# Epoch 178/300
# 150/150 [==============================] - 0s 94us/step - loss: 0.8286 - acc: 0.6533
# Epoch 179/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.8278 - acc: 0.6533
# Epoch 180/300
# 150/150 [==============================] - 0s 99us/step - loss: 0.8270 - acc: 0.6533
# Epoch 181/300
# 150/150 [==============================] - 0s 84us/step - loss: 0.8262 - acc: 0.6533
# Epoch 182/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.8254 - acc: 0.6533
# Epoch 183/300
# 150/150 [==============================] - 0s 89us/step - loss: 0.8246 - acc: 0.6533
# Epoch 184/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8238 - acc: 0.6533
# Epoch 185/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.8230 - acc: 0.6533
# Epoch 186/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.8222 - acc: 0.6533
# Epoch 187/300
# 150/150 [==============================] - 0s 86us/step - loss: 0.8214 - acc: 0.6533
# Epoch 188/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.8206 - acc: 0.6533
# Epoch 189/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.8198 - acc: 0.6533
# Epoch 190/300
# 150/150 [==============================] - 0s 82us/step - loss: 0.8191 - acc: 0.6667
# Epoch 191/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.8183 - acc: 0.6667
# Epoch 192/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.8175 - acc: 0.6667
# Epoch 193/300
# 150/150 [==============================] - 0s 98us/step - loss: 0.8167 - acc: 0.6667
# Epoch 194/300
# 150/150 [==============================] - 0s 91us/step - loss: 0.8159 - acc: 0.6667
# Epoch 195/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.8152 - acc: 0.6667
# Epoch 196/300
# 150/150 [==============================] - 0s 88us/step - loss: 0.8144 - acc: 0.6667
# Epoch 197/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.8136 - acc: 0.6733
# Epoch 198/300
# 150/150 [==============================] - 0s 88us/step - loss: 0.8128 - acc: 0.6733
# Epoch 199/300
# 150/150 [==============================] - 0s 88us/step - loss: 0.8121 - acc: 0.6733
# Epoch 200/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.8113 - acc: 0.6800
# Epoch 201/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.8105 - acc: 0.6800
# Epoch 202/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.8097 - acc: 0.6800
# Epoch 203/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.8090 - acc: 0.6800
# Epoch 204/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.8082 - acc: 0.6800
# Epoch 205/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.8075 - acc: 0.6800
# Epoch 206/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.8067 - acc: 0.6800
# Epoch 207/300
# 150/150 [==============================] - 0s 92us/step - loss: 0.8060 - acc: 0.6800
# Epoch 208/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.8052 - acc: 0.6800
# Epoch 209/300
# 150/150 [==============================] - 0s 93us/step - loss: 0.8045 - acc: 0.6800
# Epoch 210/300
# 150/150 [==============================] - 0s 106us/step - loss: 0.8037 - acc: 0.6800
# Epoch 211/300
# 150/150 [==============================] - 0s 73us/step - loss: 0.8030 - acc: 0.6800
# Epoch 212/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.8022 - acc: 0.6800
# Epoch 213/300
# 150/150 [==============================] - 0s 90us/step - loss: 0.8015 - acc: 0.6800
# Epoch 214/300
# 150/150 [==============================] - 0s 102us/step - loss: 0.8007 - acc: 0.6800
# Epoch 215/300
# 150/150 [==============================] - 0s 87us/step - loss: 0.8000 - acc: 0.6800
# Epoch 216/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.7992 - acc: 0.6800
# Epoch 217/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.7985 - acc: 0.6800
# Epoch 218/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.7978 - acc: 0.6867
# Epoch 219/300
# 150/150 [==============================] - 0s 95us/step - loss: 0.7971 - acc: 0.6867
# Epoch 220/300
# 150/150 [==============================] - 0s 116us/step - loss: 0.7963 - acc: 0.6867
# Epoch 221/300
# 150/150 [==============================] - 0s 99us/step - loss: 0.7956 - acc: 0.6867
# Epoch 222/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.7949 - acc: 0.6867
# Epoch 223/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.7941 - acc: 0.6867
# Epoch 224/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.7934 - acc: 0.6867
# Epoch 225/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.7927 - acc: 0.6867
# Epoch 226/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.7920 - acc: 0.6867
# Epoch 227/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.7913 - acc: 0.6867
# Epoch 228/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.7906 - acc: 0.6867
# Epoch 229/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.7898 - acc: 0.6867
# Epoch 230/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.7891 - acc: 0.6867
# Epoch 231/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.7884 - acc: 0.6867
# Epoch 232/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.7877 - acc: 0.6867
# Epoch 233/300
# 150/150 [==============================] - 0s 74us/step - loss: 0.7870 - acc: 0.6867
# Epoch 234/300
# 150/150 [==============================] - 0s 70us/step - loss: 0.7863 - acc: 0.6867
# Epoch 235/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.7856 - acc: 0.6867
# Epoch 236/300
# 150/150 [==============================] - 0s 92us/step - loss: 0.7849 - acc: 0.6867
# Epoch 237/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.7842 - acc: 0.6867
# Epoch 238/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.7835 - acc: 0.6867
# Epoch 239/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.7828 - acc: 0.6867
# Epoch 240/300
# 150/150 [==============================] - 0s 92us/step - loss: 0.7821 - acc: 0.6933
# Epoch 241/300
# 150/150 [==============================] - 0s 98us/step - loss: 0.7814 - acc: 0.6933
# Epoch 242/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.7808 - acc: 0.6933
# Epoch 243/300
# 150/150 [==============================] - 0s 95us/step - loss: 0.7801 - acc: 0.6933
# Epoch 244/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.7794 - acc: 0.6933
# Epoch 245/300
# 150/150 [==============================] - 0s 57us/step - loss: 0.7787 - acc: 0.6933
# Epoch 246/300
# 150/150 [==============================] - 0s 104us/step - loss: 0.7780 - acc: 0.6933
# Epoch 247/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.7774 - acc: 0.6933
# Epoch 248/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.7767 - acc: 0.7000
# Epoch 249/300
# 150/150 [==============================] - 0s 81us/step - loss: 0.7760 - acc: 0.7000
# Epoch 250/300
# 150/150 [==============================] - 0s 105us/step - loss: 0.7753 - acc: 0.7000
# Epoch 251/300
# 150/150 [==============================] - 0s 106us/step - loss: 0.7746 - acc: 0.7000
# Epoch 252/300
# 150/150 [==============================] - 0s 80us/step - loss: 0.7740 - acc: 0.7000
# Epoch 253/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.7733 - acc: 0.7000
# Epoch 254/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.7726 - acc: 0.7067
# Epoch 255/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.7720 - acc: 0.7067
# Epoch 256/300
# 150/150 [==============================] - 0s 83us/step - loss: 0.7713 - acc: 0.7067
# Epoch 257/300
# 150/150 [==============================] - 0s 78us/step - loss: 0.7706 - acc: 0.7067
# Epoch 258/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.7700 - acc: 0.7067
# Epoch 259/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.7693 - acc: 0.7067
# Epoch 260/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.7687 - acc: 0.7067
# Epoch 261/300
# 150/150 [==============================] - 0s 84us/step - loss: 0.7680 - acc: 0.7067
# Epoch 262/300
# 150/150 [==============================] - 0s 83us/step - loss: 0.7674 - acc: 0.7067
# Epoch 263/300
# 150/150 [==============================] - 0s 85us/step - loss: 0.7667 - acc: 0.7067
# Epoch 264/300
# 150/150 [==============================] - 0s 133us/step - loss: 0.7661 - acc: 0.7067
# Epoch 265/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.7654 - acc: 0.7133
# Epoch 266/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.7648 - acc: 0.7133
# Epoch 267/300
# 150/150 [==============================] - 0s 58us/step - loss: 0.7641 - acc: 0.7133
# Epoch 268/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.7635 - acc: 0.7133
# Epoch 269/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.7629 - acc: 0.7133
# Epoch 270/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.7622 - acc: 0.7133
# Epoch 271/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.7616 - acc: 0.7133
# Epoch 272/300
# 150/150 [==============================] - 0s 88us/step - loss: 0.7609 - acc: 0.7133
# Epoch 273/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.7603 - acc: 0.7133
# Epoch 274/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.7597 - acc: 0.7133
# Epoch 275/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.7590 - acc: 0.7133
# Epoch 276/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.7584 - acc: 0.7200
# Epoch 277/300
# 150/150 [==============================] - 0s 92us/step - loss: 0.7578 - acc: 0.7200
# Epoch 278/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.7571 - acc: 0.7200
# Epoch 279/300
# 150/150 [==============================] - 0s 69us/step - loss: 0.7565 - acc: 0.7200
# Epoch 280/300
# 150/150 [==============================] - 0s 76us/step - loss: 0.7559 - acc: 0.7200
# Epoch 281/300
# 150/150 [==============================] - 0s 88us/step - loss: 0.7553 - acc: 0.7267
# Epoch 282/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.7547 - acc: 0.7267
# Epoch 283/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.7540 - acc: 0.7267
# Epoch 284/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.7534 - acc: 0.7267
# Epoch 285/300
# 150/150 [==============================] - 0s 88us/step - loss: 0.7528 - acc: 0.7267
# Epoch 286/300
# 150/150 [==============================] - 0s 72us/step - loss: 0.7522 - acc: 0.7267
# Epoch 287/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.7516 - acc: 0.7267
# Epoch 288/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.7510 - acc: 0.7267
# Epoch 289/300
# 150/150 [==============================] - 0s 77us/step - loss: 0.7503 - acc: 0.7267
# Epoch 290/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.7497 - acc: 0.7267
# Epoch 291/300
# 150/150 [==============================] - 0s 75us/step - loss: 0.7491 - acc: 0.7267
# Epoch 292/300
# 150/150 [==============================] - 0s 65us/step - loss: 0.7485 - acc: 0.7267
# Epoch 293/300
# 150/150 [==============================] - 0s 71us/step - loss: 0.7479 - acc: 0.7333
# Epoch 294/300
# 150/150 [==============================] - 0s 64us/step - loss: 0.7473 - acc: 0.7333
# Epoch 295/300
# 150/150 [==============================] - 0s 63us/step - loss: 0.7467 - acc: 0.7333
# Epoch 296/300
# 150/150 [==============================] - 0s 59us/step - loss: 0.7461 - acc: 0.7333
# Epoch 297/300
# 150/150 [==============================] - 0s 66us/step - loss: 0.7455 - acc: 0.7333
# Epoch 298/300
# 150/150 [==============================] - 0s 79us/step - loss: 0.7449 - acc: 0.7333
# Epoch 299/300
# 150/150 [==============================] - 0s 83us/step - loss: 0.7443 - acc: 0.7333
# Epoch 300/300
# 150/150 [==============================] - 0s 68us/step - loss: 0.7437 - acc: 0.7333

# %%
accuracy, CM = testModel(model, 10, mean_train, stddev_train)
# Out:
# Accuracy :0.867
# Accuracy :0.750

# %% [markdown]
# # ADVANCED QUESTIONS

# %% [markdown]
# ### Effect of changing Nh
# ### Effect of changing Nepochs
# ### Effect of changing N, no. of training samples
#
# Can you observe overfitting?
#
# Can you do hyperparameter tuning here?
#
# To normalize test data, why do we use the mean and stddev of training data?
