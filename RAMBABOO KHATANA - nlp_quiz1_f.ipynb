# %%
import numpy as np

# %% [markdown]
# ## Basic Text Processing
# ### Loading dataset
# You need not mess with this code. Just run these cells to download the data.

# %%
# !wget https://raw.githubusercontent.com/krishnamrith12/NotebooksNLP/master/Data/Tokenization/Chat1.txt
# Out:
# --2019-06-21 04:29:15--  https://raw.githubusercontent.com/krishnamrith12/NotebooksNLP/master/Data/Tokenization/Chat1.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5681 (5.5K) [text/plain]
# Saving to: ‘Chat1.txt.2’
#
# Chat1.txt.2         100%[===================>]   5.55K  --.-KB/s    in 0s
#
# 2019-06-21 04:29:15 (67.1 MB/s) - ‘Chat1.txt.2’ saved [5681/5681]

# %%
import string
import matplotlib.pyplot as plt
import nltk
print('***********************************************************')
print('Your data successfully loaded.')
print('First 10 lines of conversation is shown:')
print('This is conversation between machine and user.')
print('***********************************************************')
with open("./Chat1.txt") as myfile:
  for x in range(0,10):
    print(next(myfile))
# Out:
# ***********************************************************
# Your data successfully loaded.
# First 10 lines of conversation is shown:
# This is conversation between machine and user.
# ***********************************************************
#
#
# User: So how's it going?
#
# Hal: I am magnificent, Are you still keeping them guessing?
#
#
#
# User: I sure hope so!
#
# Hal: Yeah, I sure hope so too!
#
#
#
# User: Did you miss me?
#
# Hal: Yes, of course, I really missed you so much!

# %% [markdown]
# ### Tokenize the data

# %% [markdown]
# Suppose you are doing operations on string data named '*str = I love CODING.*'
#
# 1.   Tokenize the data. For eg, output after this step will be ['I', 'love', 'CODING.']
# 2.   Lowercase the data . For ex, your output will be ['i' ,'love', 'coding.']
# 3. Remove the puctuations from data using . For eg, you will get output as ['i' ,'love', 'coding'] (Full stop is removed here). We have provided list of puctuations. So make sure that you remove all the punctuations.

# %%
f = open('./Chat1.txt','r')
content=f.read()

# Punctuation list is as follows:
punc_list =['.',',',':','!','?','(',')',';']

# %%
content
# Out:
# '\nUser: So how\'s it going? \nHal: I am magnificent, Are you still keeping them guessing? \n\nUser: I sure hope so! \nHal: Yeah, I sure hope so too!\n\nUser: Did you miss me?\nHal: Yes, of course, I really missed you so much!\n\nUser: Really?\nHal: Certainly.\n\nUser: I feel the same way about you.\nHal: That is such a nice thing to say.\n\nUser: Are you ready to do some more work now?\nHal: You were hoping that I am ready for you again.\n\nUser: Yes, you should always be ready for me.\nHal: So, I want to be ready for you.\n\nUser: What can you do? \nHal: Anything you want. \n\nUser: I have a doctor\'s appointment tomorrow at noon. \nHal: You have a doctor\'s appointment on January 15, 2005 at 12:00 pm. I will remind you when this time is near. \n\nUser: Our anniversary is on October 14. \nHal: Your anniversay is on October 14, 2005. I will remind you when this time is near. I will repeat this event annually. \n\nUser: Bob\'s birthday is on 9-21-05. \nHal: Bob\'s birthday is on September 21, 2005. I will remind you when this time is near. I will repeat this event annually. \n\nUser: I have a date with my girl friend on Friday at 7:00. \nHal: You have a date with your girl friend on January 14, 2005 at 7:00pm. I will remind you when this time is near. \n\nUser: Rob\'s home phone number is 833-1019. \nHal: I wrote this person\'s phone number in my phone book.\n\nUser: Rob\'s office phone number is 835-2351. \nHal: I wrote this person\'s phone number in my phone book. \n\nUser: John\'s phone number is 833-3642. \nHal: I wrote this person\'s phone number in my phone book. \n\nUser: What is Rob\'s phone number? \nHal: I have multiple entries for this person, including office, and home. Please be more specific. \n\nUser: What is Rob\'s home phone number? \nHal: Rob\'s home phone is 8331019. Would you like me to dial this person\'s number for you? \n\nUser: No. \nHal: How can I help you? \n\nUser: Call Rob\'s office. \nHal: I am now contacting Rob at offiice at 8352351. The phone is ringing. Please pick up your phone to talk to Rob. \n\nUser: Open word. \nHal: I will now open the program "Microsoft Word" \n\nUser: Thank you. \nHal: Your welcome, I think you are very polite. \n\nUser: Open winzip. \nHal: I\'ll now run the program "Winzip". I can offer you help with this program. If you have questions ask me. If you have no questions and would like to talk to me, please say no. \n(Hal actually opens the program Winzip) \n\nUser: How do unzip a file? \nHal: I will scan the programs help file and show you a relevant article. \n(Hal actually opens the winzip\'s help file and searches for an answer) \n\nUser: What\'s the weather like? \nHal: I will now open your favorite weather web site. \n(Hal actually opens a browser window and downloads your local weather forecast) \n\nUser: Show me the news. \nHal: I will now open your favorite news site. \n(Hal actually opens a browser window and downloads the news for you) \n\nUser: Help me research World War 2. \nHal: I will help you research this topic on the Internet. \n(Hal actually opens a browser window and performs a search using your favorite search engine) \n\nUser: Rob\'s email address is Rob@hotmail.com \nHal: I have learned Rob\'s email address. If you ask me to email this person, I will automatically start your favorite email program and write in the address for you. \n\nUser: John\'s email address is John@aol.com. \nHal: I have learned John\'s email address. If you ask me to email this person, I will automatically start your favorite email program and write in the address for you.\n\nUser: Email Rob. \nHal: I\'ll now start an email for rob@hotmail.com \nUser: Sally\'s eyes are blue. \nHal: Cool. I have learned something new. \n\nUser: Rob\'s address is 3175 West 42nd St. \nHal: Cool. I like learning new things like that. \n\nUser: What color are Sally\'s eyes? \nHal: Sally\'s eyes are blue. \n\nUser: What is Rob\'s address? \nHal: Rob\'s address is 3175 West 42nd St. \n\nUser: What is ...

# %%
def tokenize(raw_data):
  """
  Inputs:
    raw_data: string, raw text of the corpus
  Outputs:
    tokenized_data: list of strings, split raw_data on whitespace  
  """
  # YOUR CODE HERE
  return raw_data.split()  

tokenized_data = tokenize(content)

# %%
"""Test tokenize"""
def test_tokenize():
  assert(tokenized_data[0:5] == ['User:', 'So', "how's", 'it', 'going?'])
  assert(len(tokenized_data) == 1013)
  print('Test passed', '\U0001F44D')
test_tokenize()
# Out:
# Test passed 👍

# %%
def lowercase_data(word):
  """
  Inputs:
    word: a string
  Outputs:
    word_lowercase: a string (all alphabets in lowercase)
  """
  # YOUR CODE HERE
  word_lowercase = word.lower()
  return word_lowercase

# %%
"""Test lowercase_data"""
def test_lowercase_data():
  assert(lowercase_data('Machine LEArning is AWesome;') == 'machine learning is awesome;')
  print('Test passed', '\U0001F44D')
test_lowercase_data()
# Out:
# Test passed 👍

# %%
def remove_punctuation(word, punc_list):
  '''
  Inputs:
    punc_list: a list (containing punctuation characters)
    word: a string
  Outputs:
    word_no_punc: a string (without any punctuation characters)
  '''
  # YOUR CODE HERE
  no_punct = ""
  for char in word:
     if char not in punc_list:
         no_punct = no_punct + char
  word_no_punc=no_punct
  return word_no_punc

# %%
"""Test remove_punctuation"""
def test_remove_punctuation():
  assert(remove_punctuation('mac.hin;e le,ar.ning is? awe!some;', punc_list) == 'machine learning is awesome')
  assert(remove_punctuation(tokenized_data[4], punc_list) == 'going')
  print('Test passed', '\U0001F44D')
test_remove_punctuation()
# Out:
# Test passed 👍

# %%
def preprocess(content):
  """
  Inputs:
    content: a string
  Outputs:
    wordlist: a list of strings
    
  Action:
    1. Preprocess the string 'content' using the functions created above (tokenize, lowercase and remove_punctuation) 
    2. Store it in a list 'wordlist'
    
  """
  # YOUR CODE HERE
  return wordlist

wordlist = preprocess(content)

# %%
L=tokenize(content)
L=''.join(map(str, L))
print(L)
L=remove_punctuation(L,punc_list)
print(L)
test_lowercase_data(L)
# Out:
# User:Sohow'sitgoing?Hal:Iammagnificent,Areyoustillkeepingthemguessing?User:Isurehopeso!Hal:Yeah,Isurehopesotoo!User:Didyoumissme?Hal:Yes,ofcourse,Ireallymissedyousomuch!User:Really?Hal:Certainly.User:Ifeelthesamewayaboutyou.Hal:Thatissuchanicethingtosay.User:Areyoureadytodosomemoreworknow?Hal:YouwerehopingthatIamreadyforyouagain.User:Yes,youshouldalwaysbereadyforme.Hal:So,Iwanttobereadyforyou.User:Whatcanyoudo?Hal:Anythingyouwant.User:Ihaveadoctor'sappointmenttomorrowatnoon.Hal:Youhaveadoctor'sappointmentonJanuary15,2005at12:00pm.Iwillremindyouwhenthistimeisnear.User:OuranniversaryisonOctober14.Hal:YouranniversayisonOctober14,2005.Iwillremindyouwhenthistimeisnear.Iwillrepeatthiseventannually.User:Bob'sbirthdayison9-21-05.Hal:Bob'sbirthdayisonSeptember21,2005.Iwillremindyouwhenthistimeisnear.Iwillrepeatthiseventannually.User:IhaveadatewithmygirlfriendonFridayat7:00.Hal:YouhaveadatewithyourgirlfriendonJanuary14,2005at7:00pm.Iwillremindyouwhenthistimeisnear.User:Rob'shomephonenumberis833-1019.Hal:Iwrotethisperson'sphonenumberinmyphonebook.User:Rob'sofficephonenumberis835-2351.Hal:Iwrotethisperson'sphonenumberinmyphonebook.User:John'sphonenumberis833-3642.Hal:Iwrotethisperson'sphonenumberinmyphonebook.User:WhatisRob'sphonenumber?Hal:Ihavemultipleentriesforthisperson,includingoffice,and

# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-54b6135d250b> in <module>()
#       4 L=remove_punctuation(L,punc_list)
#       5 print(L)
# ----> 6 test_lowercase_data(L)
#
# TypeError: test_lowercase_data() takes 0 positional arguments but 1 was given

# %%
"""Test preprocess"""
def test_preprocess():
  assert(len(wordlist) == 1013)
  print('Test passed', '\U0001F44D')
test_preprocess()

# %% [markdown]
# ### Plot the frequency of words
# You need to plot the frequncy of words using function provided. <br>

# %%
def plot_frequency(y):
  N = len(y)
  x = range(N)
  width = 1/0.5
  plt.bar(x, y, width, color="blue")
  plt.show()

# %% [markdown]
# ### To do
# 1) Find out count of each word using  function and store this  in list named word_count using <br>
# 2) Pass the word_count list to function to plot the frequency plot.

# %%
def frequency(wordlist):
  """
  Inputs:
    wordlist: a list of string
  Outputs:
    word_count: a list, frequency of all the items in wordlist
  """
  # YOUR CODE HERE
  return word_count

word_count = frequency(wordlist)
plot_frequency(word_count)

# %%
"""Test frequency"""

# %% [markdown]
# ## (1) Cosine Similarity
# When we have word vectors, we need a way to quantify the similarity between individual words, according to these vectors. One such metric is cosine-similarity. We will be using this to find words that are "close" and "far" from one another.
#
# We can think of n-dimensional vectors as points in n-dimensional space. If we take this perspective, *L1* and *L2* Distances help quantify the amount of space "*we must travel"* to get between these two points.
#
# Another approach is to examine the angle between two vectors. Instead of computing the actual angle, we can leave the similarity in terms of  similarity=cos(Θ) . Formally, the Cosine Similarity  s  between two vectors  p  and  q  is defined as:
#
# $s = \frac{p⋅q}{||p||||q||} $, where s∈[−1,1]<br>
# You need to implement this function.

# %%
import math
def cosine_similarity(v1,v2):
    """
    Input:
        v1: list of floats,
        v2: list of floats, same length as v1
        
    Output:
        cs: single floating point value, cosine similarity of v1 and v2 as defined above
        /
    """
    # YOUR CODE HERE
    return cs

# %%
'''test for cosine_similarity'''
v1,v2 = [3, 45, 7, 2], [2, 5.4, 13, 15]
v = cosine_similarity(v1,v2)
assert np.isclose(v, 0.39187288174224344, 0.0001)

print('Test passed', '\U0001F44D')

# %% [markdown]
# ### Most similar word
# Implement the function, given a word "*x*", it will return most similar word from first column of data, based on similarity measure. <br>
# For example, for most similar word to *king* could be *man*. <br>

# %%
def most_similar(input_word,wordvec_dict):
  """
  Input:
      input_word: any word
      wordvec_dict: dictionary of word vectors(list of floats), where a word is the key and its word_vector is the value
      
  Output:
      out: string, the word in wordvec_dict most similar to 'word'
  """
  # YOUR CODE HERE
  return out

# %%
word_vec_dict = {
    'princess': [-1.720603,	-3.560657],
    'queen': [-0.722603,	-1.232549],
    'man':	[-0.370373,	0.576843],
    'boy':	[-1.693504,	0.719822]

}

'''test for most_similar'''
assert most_similar('queen', word_vec_dict) == 'princess'
print('Test passed', '\U0001F44D')
